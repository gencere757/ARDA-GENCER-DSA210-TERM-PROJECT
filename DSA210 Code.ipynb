# %% [markdown]
# <a href="https://colab.research.google.com/github/gencere757/ARDA-GENCER-DSA210-TERM-PROJECT/blob/main/DSA210%20Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
hdDF = pd.read_csv('Heart_Disease_Mortality_Data_Among_US_Adults__35___by_State_Territory_and_County___2019-2021.csv')
hdDF
# Out:
#        Year LocationAbbr           LocationDesc GeographicLevel DataSource  \
# 0      2020           AK                 Denali          County       NVSS
# 1      2020           CA             California           State       NVSS
# 2      2020           CO            Park County          County       NVSS
# 3      2020           FL          Walton County          County       NVSS
# 4      2020           GA       Whitfield County          County       NVSS
# ...     ...          ...                    ...             ...        ...
# 78787  2020           TX        Eastland County          County       NVSS
# 78788  2020           WA        San Juan County          County       NVSS
# 78789  2020           WA          Pierce County          County       NVSS
# 78790  2020           UT          Carbon County          County       NVSS
# 78791  2020           VA  Roanoke County County          County       NVSS
#
#                          Class                    Topic  Data_Value  \
# 0      Cardiovascular Diseases  Heart Disease Mortality       348.8
# 1      Cardiovascular Diseases  Heart Disease Mortality       230.1
# 2      Cardiovascular Diseases  Heart Disease Mortality       135.9
# 3      Cardiovascular Diseases  Heart Disease Mortality       126.5
# 4      Cardiovascular Diseases  Heart Disease Mortality       155.1
# ...                        ...                      ...         ...
# 78787  Cardiovascular Diseases  Heart Disease Mortality         NaN
# 78788  Cardiovascular Diseases  Heart Disease Mortality       307.7
# 78789  Cardiovascular Diseases  Heart Disease Mortality       297.2
# 78790  Cardiovascular Diseases  Heart Disease Mortality       454.7
# 78791  Cardiovascular Diseases  Heart Disease Mortality         NaN
#
#               Data_Value_Unit  \
# 0      per 100,000 population
# 1      per 100,000 population
# 2      per 100,000 population
# 3      per 100,000 population
# 4      per 100,000 population
# ...                       ...
# 78787  per 100,000 population
# 78788  per 100,000 population
# 78789  per 100,000 population
# 78790  per 100,000 population
# 78791  per 100,000 population
#
#                                          Data_Value_Type  ...  \
# 0      Age-adjusted, Spatially Smoothed, 3-year Avera...  ...
# 1                      Age-adjusted, 3-year Average Rate  ...
# 2      Age-adjusted, Spatially Smoothed, 3-year Avera...  ...
# 3      Age-adjusted, Spatially Smoothed, 3-year Avera...  ...
# 4      Age-adjusted, Spatially Smoothed, 3-year Avera...  ...
# ...                                                  ...  ...
# 78787  Age-adjusted, Spatially Smoothed, 3-year Avera...  ...
# 78788  Age-adjusted, Spatially Smoothed, 3-year Avera...  ...
# 78789  Age-adjusted, Spatially Smoothed, 3-year Avera...  ...
# 78790  Age-adjusted, Spatially Smoothed, 3-year Avera...  ...
# 78791  Age-adjusted, Spatially Smoothed, 3-year Avera...  ...
#
#       Data_Value_Footnote StratificationCategory1 Stratification1  \
# 0                     NaN                     Sex            Male
# 1                     NaN                     Sex            Male
# 2                     NaN                     Sex          Female
# 3                     NaN                     Sex          Female
# 4                     NaN                     Sex          Female
# ...                   ...                     ...             ...
# 78787   Insufficient Data                     Sex         Overall
# 78788                 NaN                     Sex            Male
# 78789                 NaN                     Sex          Female
# 78790                 NaN                     Sex            Male
# 78791   Insufficient Data                     Sex         Overall
#
#       StratificationCategory2                            Stratification2  \
# 0              Race/Ethnicity                                      White
# 1              Race/Ethnicity                         More than one race
# 2              Race/Ethnicity                                      White
# 3              Race/Ethnicity                                      Asian
# 4              Race/Ethnicity                                   Hispanic
# ...                       ...                                        ...
# 78787          Race/Ethnicity  Native Hawaiian or Other Pacific Islander
# 78788          Race/Ethnicity                                      Asian
# 78789          Race/Ethnicity           American Indian or Alaska Native
# 78790          Race/Ethnicity                                   Hispanic
# 78791          Race/Ethnicity                         More than one race
#
#       TopicID LocationID      Y_lat       X_lon  \
# 0          T2       2068  63.678820 -149.960801
# 1          T2          6  37.241400 -119.601000
# 2          T2       8093  39.115616 -105.708698
# 3          T2      12131  30.655966  -86.157457
# 4          T2      13313  34.803854  -84.962112
# ...       ...        ...        ...         ...
# 78787      T2      48133  32.332826  -98.830318
# 78788      T2      53055  48.535986 -123.082448
# 78789      T2      53053  47.016724 -122.091967
# 78790      T2      49007  39.641056 -110.580615
# 78791      T2      51161  37.216893  -80.053162
#
#                            Georeference
# 0      POINT (-149.9608012 63.67881971)
# 1              POINT (-119.601 37.2414)
# 2      POINT (-105.7086982 39.11561621)
# 3      POINT (-86.15745736 30.65596581)
# 4      POINT (-84.96211184 34.80385386)
# ...                                 ...
# 78787  POINT (-98.83031837 32.33282585)
# 78788  POINT (-123.0824477 48.53598644)
# 78789  POINT (-122.0919668 47.01672374)
# 78790     POINT (-110.580615 39.641056)
# 78791   POINT (-80.0531625 37.21689293)
#
# [78792 rows x 21 columns]

# %%
hdDF = hdDF[hdDF['GeographicLevel'] == "County"]  #Clean non county rows
hdDF_cleaned = hdDF.dropna(subset=['Data_Value']).copy()  #Clean empty values
hdDF_cleaned['Log_Mortality'] = np.log1p(hdDF_cleaned['Data_Value'])  #Create new column with log transformed values
hdDF_cleaned
# Out:
#        Year LocationAbbr           LocationDesc GeographicLevel DataSource  \
# 0      2020           AK                 Denali          County       NVSS
# 2      2020           CO            Park County          County       NVSS
# 3      2020           FL          Walton County          County       NVSS
# 4      2020           GA       Whitfield County          County       NVSS
# 6      2020           IA             Ida County          County       NVSS
# ...     ...          ...                    ...             ...        ...
# 78784  2020           VA  Prince William County          County       NVSS
# 78786  2020           WI       Menominee County          County       NVSS
# 78788  2020           WA        San Juan County          County       NVSS
# 78789  2020           WA          Pierce County          County       NVSS
# 78790  2020           UT          Carbon County          County       NVSS
#
#                          Class                    Topic  Data_Value  \
# 0      Cardiovascular Diseases  Heart Disease Mortality       348.8
# 2      Cardiovascular Diseases  Heart Disease Mortality       135.9
# 3      Cardiovascular Diseases  Heart Disease Mortality       126.5
# 4      Cardiovascular Diseases  Heart Disease Mortality       155.1
# 6      Cardiovascular Diseases  Heart Disease Mortality       168.0
# ...                        ...                      ...         ...
# 78784  Cardiovascular Diseases  Heart Disease Mortality       228.4
# 78786  Cardiovascular Diseases  Heart Disease Mortality       451.7
# 78788  Cardiovascular Diseases  Heart Disease Mortality       307.7
# 78789  Cardiovascular Diseases  Heart Disease Mortality       297.2
# 78790  Cardiovascular Diseases  Heart Disease Mortality       454.7
#
#               Data_Value_Unit  \
# 0      per 100,000 population
# 2      per 100,000 population
# 3      per 100,000 population
# 4      per 100,000 population
# 6      per 100,000 population
# ...                       ...
# 78784  per 100,000 population
# 78786  per 100,000 population
# 78788  per 100,000 population
# 78789  per 100,000 population
# 78790  per 100,000 population
#
#                                          Data_Value_Type  ...  \
# 0      Age-adjusted, Spatially Smoothed, 3-year Avera...  ...
# 2      Age-adjusted, Spatially Smoothed, 3-year Avera...  ...
# 3      Age-adjusted, Spatially Smoothed, 3-year Avera...  ...
# 4      Age-adjusted, Spatially Smoothed, 3-year Avera...  ...
# 6      Age-adjusted, Spatially Smoothed, 3-year Avera...  ...
# ...                                                  ...  ...
# 78784  Age-adjusted, Spatially Smoothed, 3-year Avera...  ...
# 78786  Age-adjusted, Spatially Smoothed, 3-year Avera...  ...
# 78788  Age-adjusted, Spatially Smoothed, 3-year Avera...  ...
# 78789  Age-adjusted, Spatially Smoothed, 3-year Avera...  ...
# 78790  Age-adjusted, Spatially Smoothed, 3-year Avera...  ...
#
#       StratificationCategory1 Stratification1 StratificationCategory2  \
# 0                         Sex            Male          Race/Ethnicity
# 2                         Sex          Female          Race/Ethnicity
# 3                         Sex          Female          Race/Ethnicity
# 4                         Sex          Female          Race/Ethnicity
# 6                         Sex         Overall          Race/Ethnicity
# ...                       ...             ...                     ...
# 78784                     Sex         Overall          Race/Ethnicity
# 78786                     Sex            Male          Race/Ethnicity
# 78788                     Sex            Male          Race/Ethnicity
# 78789                     Sex          Female          Race/Ethnicity
# 78790                     Sex            Male          Race/Ethnicity
#
#                         Stratification2 TopicID LocationID      Y_lat  \
# 0                                 White      T2       2068  63.678820
# 2                                 White      T2       8093  39.115616
# 3                                 Asian      T2      12131  30.655966
# 4                              Hispanic      T2      13313  34.803854
# 6                              Hispanic      T2      19093  42.387689
# ...                                 ...     ...        ...        ...
# 78784                             White      T2      51153  38.704617
# 78786                             White      T2      55078  45.005150
# 78788                             Asian      T2      53055  48.535986
# 78789  American Indian or Alaska Native      T2      53053  47.016724
# 78790                          Hispanic      T2      49007  39.641056
#
#             X_lon                      Georeference  Log_Mortality
# 0     -149.960801  POINT (-149.9608012 63.67881971)       5.857362
# 2     -105.708698  POINT (-105.7086982 39.11561621)       4.919251
# 3      -86.157457  POINT (-86.15745736 30.65596581)       4.848116
# 4      -84.962112  POINT (-84.96211184 34.80385386)       5.050497
# 6      -95.523143  POINT (-95.52314316 42.38768939)       5.129899
# ...           ...                               ...            ...
# 78784  -77.481441  POINT (-77.48144058 38.70461706)       5.435467
# 78786  -88.704268  POINT (-88.70426767 45.00514971)       6.115230
# 78788 -123.082448  POINT (-123.0824477 48.53598644)       5.732370
# 78789 -122.091967  POINT (-122.0919668 47.01672374)       5.697764
# 78790 -110.580615     POINT (-110.580615 39.641056)       6.121835
#
# [33431 rows x 22 columns]

# %%
walkDF = pd.read_csv('WalkabilityIndexByCounty.csv')
walkDF
# Out:
#       Unnamed: 0  GEOID10  NatWalkInd         County
# 0              1     1001    5.234375        Autauga
# 1              2     1003    6.450355        Baldwin
# 2              3     1005    5.188406        Barbour
# 3              4     1007    5.033333           Bibb
# 4              5     1009    4.666667         Blount
# ...          ...      ...         ...            ...
# 1897        3607    72139    4.865079  Trujillo Alto
# 1898        3609    72143    4.015152      Vega Alta
# 1899        3611    72145    4.450450      Vega Baja
# 1900        3614    72149    3.254902       Villalba
# 1901        3616    72153    4.559524          Yauco
#
# [1902 rows x 4 columns]

# %%
foodDF = pd.read_csv('StateAndCountyData.csv')
restaurantDF = foodDF[foodDF['Variable_Code'] == "FFRPTH20"]   #Fast food restaurants per 1000 people in county
restaurantDF = restaurantDF[restaurantDF['Value']>0].copy()
restaurantDF['Log_Transformed_Restaurants'] = np.log1p(restaurantDF['Value'])
restaurantDF
# Out:
#            FIPS State      County Variable_Code     Value  \
# 728093   1001.0    AL     Autauga      FFRPTH20  0.801496
# 728105   1003.0    AL     Baldwin      FFRPTH20  0.750152
# 728117   1005.0    AL     Barbour      FFRPTH20  0.976046
# 728129   1007.0    AL        Bibb      FFRPTH20  0.316227
# 728141   1009.0    AL      Blount      FFRPTH20  0.414658
# ...         ...   ...         ...           ...       ...
# 765725  56031.0    WY      Platte      FFRPTH20  0.466309
# 765737  56033.0    WY    Sheridan      FFRPTH20  0.680426
# 765761  56037.0    WY  Sweetwater      FFRPTH20  0.609285
# 765773  56039.0    WY       Teton      FFRPTH20  0.680938
# 765785  56041.0    WY       Uinta      FFRPTH20  0.692555
#
#         Log_Transformed_Restaurants
# 728093                     0.588618
# 728105                     0.559702
# 728117                     0.681098
# 728129                     0.274769
# 728141                     0.346888
# ...                             ...
# 765725                     0.382748
# 765737                     0.519048
# 765761                     0.475790
# 765773                     0.519352
# 765785                     0.526239
#
# [2672 rows x 6 columns]

# %%
plt.hist(walkDF['NatWalkInd'], bins = 100, edgecolor = 'black')
plt.title("Distribution Of Walkability Index")
plt.xlabel("Walkability Index")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(restaurantDF['Log_Transformed_Restaurants'], bins = 100, edgecolor = 'black')
plt.title("Distribution Of Fast Food Restaurants Per 1000 Population")
plt.xlabel("Number of Restaurants Per 1000 Population")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(hdDF_cleaned['Log_Mortality'], bins = 100, edgecolor = 'black')
plt.title("Distribution Of Heart Disease Mortality")
plt.xlabel("Heart Disease Mortality Rate (Log Transformed)")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')
